# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2
import tensorflow as tf
from tensorflow.keras.metrics import AUC
# Out:
# 2024-05-15 20:12:15.079538: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-15 20:12:15.079670: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-15 20:12:15.221404: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
print(tf.config.list_physical_devices("GPU"))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
IMG_SIZE = 512
BATCH_SIZE = 8
IMG_CHANNELS = 3

# %%
import shutil
import os

# Source and destination paths
source_path = "/kaggle/input/mias-mammography/all-mias/"
destination_path = "/kaggle/working/all-mias0/"

# Create the destination folder if it doesn't exist
os.makedirs(destination_path, exist_ok=True)

# Get a list of all files in the source folder
files = os.listdir(source_path)

# Copy each file from the source folder to the destination folder
for file in files:
    source_file_path = os.path.join(source_path, file)
    destination_file_path = os.path.join(destination_path, file)
    shutil.copy2(source_file_path, destination_file_path)

# %%
def convert_pgm_to_jpg(input_folder, output_folder):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate through each file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(".pgm"):
            input_path = os.path.join(input_folder, filename)
            output_path = os.path.join(output_folder, filename.replace(".pgm", ".jpg"))

            # Convert PGM to JPG
            with open(input_path, 'rb') as f:
                # Read the header
                magic_number = f.readline().decode().strip()
                width, height = map(int, f.readline().decode().split())
                max_val = int(f.readline().decode())

                # Check if it's a valid PGM file
                if magic_number != 'P5':
                    print("Error: Not a valid PGM file")
                    continue

                # Read the pixel data
                pixel_data = f.read()

            # Create a grayscale mode image using Pillow
            img = Image.frombytes('L', (width, height), pixel_data)

            # Save the image as a JPEG file
            img.save(output_path, format='JPEG')

# %%
source_path = "/kaggle/working/all-mias0"
jpg_path = "/kaggle/working/all-mias"
if not os.path.exists(jpg_path):
    os.makedirs(jpg_path)
convert_pgm_to_jpg(source_path, jpg_path)

# %%
data = pd.read_csv('/kaggle/input/mias-mammography/Info.txt', sep=" ", header=None)
data.columns = ["REFNUM", "BG", "CLASS", "SEVERITY", "X", "Y", "RADIUS", "Naveed" ]

del data['Naveed']

data = data.drop(data.index[0])
data['SEVERITY'] = data['SEVERITY'].fillna('N')
data = data.fillna(0)
data1 = data['BG']

for i in data.index:
    data.loc[i, 'REFNUM'] = '/kaggle/working/all-mias/' + data.loc[i, 'REFNUM'] +'.jpg'
    data.loc[i, 'X'] = int((int(data.loc[i, 'X']))*(IMG_SIZE/1024))
    if data.loc[i, 'Y'] != 0:
        data.loc[i, 'Y'] = int(IMG_SIZE - (int(data.loc[i, 'Y']) *(IMG_SIZE/1024)))
    data.loc[i, 'RADIUS'] = int((int(data.loc[i, 'RADIUS']))*(IMG_SIZE/1024))

# %%
data_shape = np.shape(data)
if data_shape[1] > 6:
    del data['BG']
    del data['CLASS']
print(data)
# Out:
#                                   REFNUM SEVERITY    X    Y RADIUS
# 1    /kaggle/working/all-mias/mdb001.jpg        B  267  299     98
# 2    /kaggle/working/all-mias/mdb002.jpg        B  261  372     34
# 3    /kaggle/working/all-mias/mdb003.jpg        N    0    0      0
# 4    /kaggle/working/all-mias/mdb004.jpg        N    0    0      0
# 5    /kaggle/working/all-mias/mdb005.jpg        B  238  445     15
# ..                                   ...      ...  ...  ...    ...
# 326  /kaggle/working/all-mias/mdb318.jpg        N    0    0      0
# 327  /kaggle/working/all-mias/mdb319.jpg        N    0    0      0
# 328  /kaggle/working/all-mias/mdb320.jpg        N    0    0      0
# 329  /kaggle/working/all-mias/mdb321.jpg        N    0    0      0
# 330  /kaggle/working/all-mias/mdb322.jpg        N    0    0      0
#
# [330 rows x 5 columns]

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def square_img(image_path):
    # Load the image
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    # Get image dimensions
    height, width = image.shape

    # Determine the size of the square image
    max_dim = max(height, width)
    
    # Create a black square image with dimensions equal to the maximum dimension
    square_image = np.zeros((max_dim, max_dim), dtype=np.uint8)

    # Calculate the position to paste the original image in the square image
    x_offset = (max_dim - width) // 2
    y_offset = (max_dim - height) // 2

    # Paste the original image into the square image
    square_image[y_offset:y_offset+height, x_offset:x_offset+width] = image
    image_shape = square_image.shape
    
    
    return square_image, image_shape

def process_image(image_path):

    # Threshold the image to obtain binary image
    square_image, image_shape = square_img(image_path)
    
    #square_image = cv2.cvtColor(square_image, cv2.COLOR_BGR2GRAY)
    _, thresholded = cv2.threshold(square_image, 240, 255, cv2.THRESH_BINARY)

    # Find contours in the binary image
    contours, _ = cv2.findContours(thresholded, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    x, y, radius = 0, 0, 0  # Default values
    
    # Iterate through the contours
    for contour in contours:
        (x, y), radius = cv2.minEnclosingCircle(contour)
        
        # Draw the circle
        x = int(x)
        y = int(y)
        radius = int(radius)
   
    return x,y,radius

# %%
import os
import cv2
import random

def copy_and_process_images(source_directory, destination_path, Severity):
    """
    Copies images from source directory to destination directory based on specified conditions.
    
    Args:
    - source_directory (str): Path to the source directory containing images.
    - destination_path (str): Path to the destination directory where images will be copied.
    
    Returns:
    - flipped_images (list): List of dictionaries containing information about copied images.
    """
    options = [1, 2]
    
    # Create the destination folder if it doesn't exist
    os.makedirs(destination_path, exist_ok=True)
    
    
    
    flipped_images = []
    
    # Iterate through each folder in the source directory
    for root, dirs, files in os.walk(source_directory):
        
        if source_directory[-6:] == "Normal":
            chosen_option = random.choice(options)
            if chosen_option == 1:
                substring3 = substring1 = 'LEFT_MLO.jpg'
            else:
                substring3 = substring1 = 'RIGHT_MLO.jpg'
        else:
            # Define the substrings you are looking for in the file names
            substring1 = 'LEFT_CC_Mask.jpg'
            substring2 = 'RIGHT_CC_Mask.jpg'
            substring3 = 'LEFT_CC.jpg'
            substring4 = 'RIGHT_CC.jpg'
            
            
            
        # Check if the folder contains a file with substring1
        if any(substring1 in file for file in files):
            if source_directory[-6:] == "Normal":
                X = Y = R = 0
            else:
                file_with_substring1 = next(os.path.join(root, file) for file in files if substring1 in file)
                X, Y, R = process_image(file_with_substring1)  # Assuming you have a function named process_image
            # Find the file with substring3 and copy it
            for file in files:
                if substring3 in file:
                    # Create the source file path
                    source_file_path = os.path.join(root, file)
                    # Process the image and get the processed image
                    processed_image, image_shape = square_img(source_file_path)  # Assuming you have a function named square_img
                    # Create the destination file path
                    destination_file_path = os.path.join(destination_path, file)
                    # Save the processed image
                    cv2.imwrite(destination_file_path, processed_image)
                    flipped_images.append({
                        'REFNUM': destination_file_path,
                        'SEVERITY': Severity,
                        'X': X,
                        'Y': Y,
                        'RADIUS': R,
                        'Image Shape': image_shape[0]
                    })
#                     print(f"File '{file}' copied successfully.")
        
        # Check if the folder contains a file with substring2
        elif any(substring2 in file for file in files):
            if source_directory[-6:] == "Normal":
                X = Y = R = 0
            else:
                file_with_substring2 = next(os.path.join(root, file) for file in files if substring2 in file)
                X, Y, R = process_image(file_with_substring2)  # Assuming you have a function named process_image
            # Find the file with substring4 and copy it
            for file in files:
                if substring4 in file:
                    # Create the source file path
                    source_file_path = os.path.join(root, file)
                    # Process the image and get the processed image
                    processed_image, image_shape = square_img(source_file_path)  # Assuming you have a function named square_img
                    # Create the destination file path
                    destination_file_path = os.path.join(destination_path, file)
                    # Save the processed image
                    cv2.imwrite(destination_file_path, processed_image)
                    flipped_images.append({
                        'REFNUM': destination_file_path,
                        'SEVERITY': Severity,
                        'X': X,
                        'Y': Y,
                        'RADIUS': R,
                        'Image Shape': image_shape[0]
                    })
#                     print(f"File '{file}' copied successfully.")
    
    print("Files copied according to the specified conditions.")
    return flipped_images

# %%
import pandas as pd

source_directory_C = '/kaggle/input/miniddsm2/MINI-DDSM-Complete-JPEG-8/Cancer'
destination_path_C = "/kaggle/working/cancer/"

source_directory_N = '/kaggle/input/miniddsm2/MINI-DDSM-Complete-JPEG-8/Normal'
destination_path_N = "/kaggle/working/normal/"

images_DFC = pd.DataFrame(copy_and_process_images(source_directory_C, destination_path_C, "M"))
images_DFN = pd.DataFrame(copy_and_process_images(source_directory_N, destination_path_N, "N"))
# Out:
# Files copied according to the specified conditions.
# Files copied according to the specified conditions.

# %%
print(len(images_DFC))
print(len(images_DFN))
# Out:
# 644
# 602

# %%
data2 = pd.concat([images_DFC, images_DFN])
data2 = data2.sample(frac=1).reset_index(drop = True)
data2
# Out:
#                                              REFNUM SEVERITY     X     Y  \
# 0      /kaggle/working/normal/A_0608_1.LEFT_MLO.jpg        N     0     0
# 1       /kaggle/working/cancer/A_1873_1.LEFT_CC.jpg        M  1546  1569
# 2       /kaggle/working/cancer/B_3108_1.LEFT_CC.jpg        M  1014  1876
# 3      /kaggle/working/cancer/C_0342_1.RIGHT_CC.jpg        M  2116  1284
# 4       /kaggle/working/cancer/D_4053_1.LEFT_CC.jpg        M  1381  1219
# ...                                             ...      ...   ...   ...
# 1241   /kaggle/working/cancer/A_1574_1.RIGHT_CC.jpg        M   967  1481
# 1242   /kaggle/working/cancer/C_0095_1.RIGHT_CC.jpg        M  2186   514
# 1243   /kaggle/working/cancer/C_0127_1.RIGHT_CC.jpg        M  1672   854
# 1244  /kaggle/working/normal/A_0526_1.RIGHT_MLO.jpg        N     0     0
# 1245  /kaggle/working/normal/A_0319_1.RIGHT_MLO.jpg        N     0     0
#
#       RADIUS  Image Shape
# 0          0         3211
# 1         49         2746
# 2        105         2412
# 3        593         2884
# 4        150         2633
# ...      ...          ...
# 1241     157         2746
# 1242     211         2944
# 1243     134         2404
# 1244       0         2746
# 1245       0         2746
#
# [1246 rows x 6 columns]

# %%
def resize_image(df, new_size = (IMG_SIZE,IMG_SIZE)):
    for index, row in df.iterrows():
        image_path = row['REFNUM']
        image = cv2.imread(image_path)
        resized_image = cv2.resize(image, new_size)
        cv2.imwrite(image_path, resized_image)
resize_image(data2)
data2
# Out:
#                                              REFNUM SEVERITY     X     Y  \
# 0      /kaggle/working/normal/A_0608_1.LEFT_MLO.jpg        N     0     0
# 1       /kaggle/working/cancer/A_1873_1.LEFT_CC.jpg        M  1546  1569
# 2       /kaggle/working/cancer/B_3108_1.LEFT_CC.jpg        M  1014  1876
# 3      /kaggle/working/cancer/C_0342_1.RIGHT_CC.jpg        M  2116  1284
# 4       /kaggle/working/cancer/D_4053_1.LEFT_CC.jpg        M  1381  1219
# ...                                             ...      ...   ...   ...
# 1241   /kaggle/working/cancer/A_1574_1.RIGHT_CC.jpg        M   967  1481
# 1242   /kaggle/working/cancer/C_0095_1.RIGHT_CC.jpg        M  2186   514
# 1243   /kaggle/working/cancer/C_0127_1.RIGHT_CC.jpg        M  1672   854
# 1244  /kaggle/working/normal/A_0526_1.RIGHT_MLO.jpg        N     0     0
# 1245  /kaggle/working/normal/A_0319_1.RIGHT_MLO.jpg        N     0     0
#
#       RADIUS  Image Shape
# 0          0         3211
# 1         49         2746
# 2        105         2412
# 3        593         2884
# 4        150         2633
# ...      ...          ...
# 1241     157         2746
# 1242     211         2944
# 1243     134         2404
# 1244       0         2746
# 1245       0         2746
#
# [1246 rows x 6 columns]

# %%
scaling_factor = IMG_SIZE / data2['Image Shape']
columns_to_scale = ['X', 'Y', 'RADIUS']
data2[columns_to_scale] = data2[columns_to_scale].multiply(scaling_factor, axis=0)

# %%
del data2['Image Shape']
data2
# Out:
#                                              REFNUM SEVERITY           X  \
# 0      /kaggle/working/normal/A_0608_1.LEFT_MLO.jpg        N    0.000000
# 1       /kaggle/working/cancer/A_1873_1.LEFT_CC.jpg        M  288.256373
# 2       /kaggle/working/cancer/B_3108_1.LEFT_CC.jpg        M  215.243781
# 3      /kaggle/working/cancer/C_0342_1.RIGHT_CC.jpg        M  375.656033
# 4       /kaggle/working/cancer/D_4053_1.LEFT_CC.jpg        M  268.542347
# ...                                             ...      ...         ...
# 1241   /kaggle/working/cancer/A_1574_1.RIGHT_CC.jpg        M  180.300073
# 1242   /kaggle/working/cancer/C_0095_1.RIGHT_CC.jpg        M  380.173913
# 1243   /kaggle/working/cancer/C_0127_1.RIGHT_CC.jpg        M  356.099834
# 1244  /kaggle/working/normal/A_0526_1.RIGHT_MLO.jpg        N    0.000000
# 1245  /kaggle/working/normal/A_0319_1.RIGHT_MLO.jpg        N    0.000000
#
#                Y      RADIUS
# 0       0.000000    0.000000
# 1     292.544792    9.136198
# 2     398.222222   22.288557
# 3     227.950069  105.276006
# 4     237.040638   29.168249
# ...          ...         ...
# 1241  276.136926   29.273125
# 1242   89.391304   36.695652
# 1243  181.883527   28.539101
# 1244    0.000000    0.000000
# 1245    0.000000    0.000000
#
# [1246 rows x 5 columns]

# %%
main_data = pd.concat([data, data2])

# %%
from sklearn.utils import shuffle
# Shuffle the rows
main_data = shuffle(main_data).reset_index(drop=True)
columns_to_convert = ['X', 'Y', 'RADIUS'] 
main_data[columns_to_convert] = main_data[columns_to_convert].astype(int)
main_data
# Out:
#                                             REFNUM SEVERITY    X    Y  RADIUS
# 0     /kaggle/working/normal/A_0597_1.LEFT_MLO.jpg        N    0    0       0
# 1     /kaggle/working/cancer/A_1486_1.RIGHT_CC.jpg        M  247  272      41
# 2      /kaggle/working/cancer/C_0065_1.LEFT_CC.jpg        M  136  139      26
# 3              /kaggle/working/all-mias/mdb003.jpg        N    0    0       0
# 4     /kaggle/working/cancer/A_1618_1.RIGHT_CC.jpg        M  141  314      18
# ...                                            ...      ...  ...  ...     ...
# 1571  /kaggle/working/normal/A_0111_1.LEFT_MLO.jpg        N    0    0       0
# 1572  /kaggle/working/cancer/D_4127_1.RIGHT_CC.jpg        M  328  330      43
# 1573  /kaggle/working/cancer/C_0195_1.RIGHT_CC.jpg        M  376  182      66
# 1574   /kaggle/working/cancer/D_4115_1.LEFT_CC.jpg        M  151  136      34
# 1575           /kaggle/working/all-mias/mdb310.jpg        N    0    0       0
#
# [1576 rows x 5 columns]

# %%
DFM = main_data
DFN = main_data

condition = (main_data['SEVERITY'] == "B") | (main_data['SEVERITY'] == "M")
DFN = main_data[~condition].reset_index(drop=True)

condition = (main_data['SEVERITY'] == "B") | (main_data['SEVERITY'] == "N")
DFM = main_data[~condition].reset_index(drop=True)

print(len(DFM))
print(len(DFN))
# Out:
# 698
# 809

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

def plot_images_with_circles_and_labels(dataframe, rows=5, cols=3, image_size=512):
    fig, axes = plt.subplots(rows, cols, figsize=(cols*3, rows*3))

    for i in range(rows):
        for j in range(cols):
            index = np.random.randint(0, len(dataframe))  # Randomly select an index
            img_path = dataframe.iloc[index, 0]
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Read image in grayscale
            img = cv2.resize(img, (image_size, image_size))
            x = int(dataframe.iloc[index, 2])
            y = int(dataframe.iloc[index, 3])
            radius = int(dataframe.iloc[index, 4])
            cv2.circle(img, (x, y), radius, (255, 0, 0), 4)  # Draw circle
            axes[i, j].imshow(img, cmap='gray')  # Plot in grayscale
            axes[i, j].axis('off')
            label = dataframe.iloc[index, 1]
            axes[i, j].set_title(f"Severity: {label}", fontsize=12)
    
    plt.tight_layout()
    plt.show()

# %%
DFM = DFM[DFM['RADIUS'] >= 10]
DFN = DFN.sample(n=650, random_state=42)
print(len(DFM))
print(len(DFN))
# Out:
# 649
# 650

# %%
plot_images_with_circles_and_labels(DFM, rows=2, cols=3)
plot_images_with_circles_and_labels(DFN, rows=2, cols=3)

# %%
test_split_M = 195
test_split_N = 195
# Shuffle the rows of each DataFrame
DFM_shuffled = shuffle(DFM,random_state=80)
DFN_shuffled = shuffle(DFN,random_state=90)

# %%
# Select the first 41 rows from each shuffled DataFrame
dftest = pd.concat( [DFM_shuffled.iloc[:test_split_M], DFN_shuffled.iloc[:test_split_N]], ignore_index=True)
dftest = shuffle(dftest)

# Select the remaining rows (starting from the 42nd row) from each shuffled DataFrame
dftrain = pd.concat([DFM_shuffled.iloc[test_split_M:], DFN_shuffled.iloc[test_split_N:]], ignore_index=True)
dftrain = shuffle(dftrain)
# Check the number of rows in each DataFrame
print("Number of rows in dftest:", len(dftest))
print("Number of rows in dftrain:", len(dftrain))
# Out:
# Number of rows in dftest: 390
# Number of rows in dftrain: 909

# %%
#dftest['SEVERITY'] = dftest['SEVERITY'].replace({'N':0, 'B': 1, 'M': 2})
#dftrain['SEVERITY'] = dftrain['SEVERITY'].replace({'N':0, 'B': 1, 'M': 2})

dftest = dftest.reset_index(drop=True)
dftrain = dftrain.reset_index(drop=True)

# %%
dftrain
# Out:
#                                            REFNUM SEVERITY    X    Y  RADIUS
# 0    /kaggle/working/cancer/B_3074_1.RIGHT_CC.jpg        M  395  395      15
# 1    /kaggle/working/normal/D_4546_1.LEFT_MLO.jpg        N    0    0       0
# 2    /kaggle/working/cancer/A_1577_1.RIGHT_CC.jpg        M  223  210      34
# 3    /kaggle/working/normal/A_0708_1.LEFT_MLO.jpg        N    0    0       0
# 4    /kaggle/working/normal/A_0528_1.LEFT_MLO.jpg        N    0    0       0
# ..                                            ...      ...  ...  ...     ...
# 904  /kaggle/working/normal/A_0497_1.LEFT_MLO.jpg        N    0    0       0
# 905  /kaggle/working/normal/A_0484_1.LEFT_MLO.jpg        N    0    0       0
# 906           /kaggle/working/all-mias/mdb162.jpg        N    0    0       0
# 907  /kaggle/working/normal/A_0343_1.LEFT_MLO.jpg        N    0    0       0
# 908  /kaggle/working/cancer/C_0194_1.RIGHT_CC.jpg        M  311  255      44
#
# [909 rows x 5 columns]

# %%
dftest
# Out:
#                                             REFNUM SEVERITY    X    Y  RADIUS
# 0     /kaggle/working/cancer/B_3513_1.RIGHT_CC.jpg        M  390  118      30
# 1              /kaggle/working/all-mias/mdb221.jpg        N    0    0       0
# 2      /kaggle/working/cancer/A_1469_1.LEFT_CC.jpg        M  245  351      19
# 3      /kaggle/working/cancer/A_1589_1.LEFT_CC.jpg        M  359  140      28
# 4              /kaggle/working/all-mias/mdb229.jpg        N    0    0       0
# ..                                             ...      ...  ...  ...     ...
# 385  /kaggle/working/normal/A_0365_1.RIGHT_MLO.jpg        N    0    0       0
# 386    /kaggle/working/cancer/C_0137_1.LEFT_CC.jpg        M  217  268      67
# 387   /kaggle/working/cancer/D_4049_1.RIGHT_CC.jpg        M  369  128      37
# 388    /kaggle/working/cancer/C_0059_1.LEFT_CC.jpg        M  268  234      44
# 389            /kaggle/working/all-mias/mdb029.jpg        N    0    0       0
#
# [390 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
dftrain['severity_encoded'] = label_encoder.fit_transform(dftrain['SEVERITY'])
dftest['severity_encoded'] = label_encoder.fit_transform(dftest['SEVERITY'])
dftrain
# Out:
#                                            REFNUM SEVERITY    X    Y  RADIUS  \
# 0    /kaggle/working/cancer/B_3074_1.RIGHT_CC.jpg        M  395  395      15
# 1    /kaggle/working/normal/D_4546_1.LEFT_MLO.jpg        N    0    0       0
# 2    /kaggle/working/cancer/A_1577_1.RIGHT_CC.jpg        M  223  210      34
# 3    /kaggle/working/normal/A_0708_1.LEFT_MLO.jpg        N    0    0       0
# 4    /kaggle/working/normal/A_0528_1.LEFT_MLO.jpg        N    0    0       0
# ..                                            ...      ...  ...  ...     ...
# 904  /kaggle/working/normal/A_0497_1.LEFT_MLO.jpg        N    0    0       0
# 905  /kaggle/working/normal/A_0484_1.LEFT_MLO.jpg        N    0    0       0
# 906           /kaggle/working/all-mias/mdb162.jpg        N    0    0       0
# 907  /kaggle/working/normal/A_0343_1.LEFT_MLO.jpg        N    0    0       0
# 908  /kaggle/working/cancer/C_0194_1.RIGHT_CC.jpg        M  311  255      44
#
#      severity_encoded
# 0                   0
# 1                   1
# 2                   0
# 3                   1
# 4                   1
# ..                ...
# 904                 1
# 905                 1
# 906                 1
# 907                 1
# 908                 0
#
# [909 rows x 6 columns]

# %%
max_x1 = np.max(dftest['X'])
max_x2 = np.max(dftrain['X'])
max_y1 = np.max(dftrain['Y'])
max_y2 = np.max(dftest['Y'])
max_radius1 = np.max(dftest['RADIUS'])
max_radius2 = np.max(dftest['RADIUS'])
numbers = tf.constant([max_x1, max_y1, max_radius1, max_radius2], dtype=tf.float32)
max_scaler = tf.reduce_max(numbers)
max_scaler = np.array(max_scaler)

# %%
def preprocess_image(image_path, label, x, y, radius):
    # Load and preprocess the image
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=1)
    img = tf.image.resize(img, (IMG_SIZE, IMG_SIZE))
    img = img / 255.0  # Normalize pixel values
    x = tf.cast(x, tf.float32) / max_scaler
    y = tf.cast(y, tf.float32) / max_scaler
    radius = tf.cast(radius, tf.float32) / max_scaler
    
    # Return image and labels
    return img, {'classification': tf.one_hot(label, depth = 1),
                 'localization': tf.convert_to_tensor([x, y, radius], dtype=tf.float32)}

# %%
# Convert columns to numeric data types
dftrain['X'] = pd.to_numeric(dftrain['X'], errors='coerce')
dftrain['Y'] = pd.to_numeric(dftrain['Y'], errors='coerce')
dftrain['RADIUS'] = pd.to_numeric(dftrain['RADIUS'], errors='coerce')

# Drop rows with NaN values if necessary
dftrain.dropna(subset=['X', 'Y', 'RADIUS'], inplace=True)


dftest['X'] = pd.to_numeric(dftest['X'], errors='coerce')
dftest['Y'] = pd.to_numeric(dftest['Y'], errors='coerce')
dftest['RADIUS'] = pd.to_numeric(dftest['RADIUS'], errors='coerce')

# Drop rows with NaN values if necessary
dftest.dropna(subset=['X', 'Y', 'RADIUS'], inplace=True)

# %%
# Create TensorFlow Dataset with image paths and other relevant information
train_dataset = tf.data.Dataset.from_tensor_slices((dftrain['REFNUM'].values,
                                                    dftrain['severity_encoded'].values,
                                                    dftrain['X'].values,
                                                    dftrain['Y'].values,
                                                    dftrain['RADIUS'].values))


# Create TensorFlow Dataset for test data
test_dataset = tf.data.Dataset.from_tensor_slices((dftest['REFNUM'].values,
                                                   dftest['severity_encoded'].values,
                                                   dftest['X'].values,
                                                   dftest['Y'].values,
                                                   dftest['RADIUS'].values))

# %%
# Map the preprocessing function to load and preprocess each image
training_dataset = train_dataset.map(lambda image_path, label, x, y, radius:
                                  preprocess_image(image_path, label, x, y, radius),
                                  num_parallel_calls=tf.data.experimental.AUTOTUNE)
# Map the preprocessing function to load and preprocess each image
test_dataset = test_dataset.map(lambda image_path, label, x, y, radius:
                                preprocess_image(image_path, label, x, y, radius),
                                num_parallel_calls=tf.data.experimental.AUTOTUNE)

# %%
train_dataset = training_dataset.shuffle(buffer_size=1000).batch(BATCH_SIZE).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
test_dataset = test_dataset.batch(BATCH_SIZE).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
import matplotlib.pyplot as plt

# Define a function to visualize the dataset
def visualize_dataset(dataset, num_samples=1):
    # Iterate through the dataset and display images with labels
    for image_batch, labels_batch in dataset.take(num_samples):
        for i in range(len(image_batch)):
            img = image_batch[i].numpy()  # Convert TensorFlow tensor to NumPy array
            classification_label = labels_batch['classification'][i].numpy()
            localization_label = labels_batch['localization'][i].numpy()
            
            # Display image
            plt.imshow(img)
            print(np.shape(img))
            plt.axis('off')
            plt.show()
            
            # Print labels
            print("Classification Label:", classification_label)
            print("Localization Label:", localization_label)
            break
        break

# %%
# Visualize the first few samples from the dataset
visualize_dataset(train_dataset)
# Out:
# (512, 512, 1)
# Classification Label: [0.]
# Localization Label: [0. 0. 0.]

# %%
# Visualize the first few samples from the dataset
visualize_dataset(test_dataset)
# Out:
# (512, 512, 1)
# Classification Label: [1.]
# Localization Label: [0.9489051  0.28710464 0.0729927 ]

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy, MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError, Accuracy
import math
import tensorflow.keras.backend as K


def r_squared(y_true, y_pred):
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )




## Input layer
inputs = tf.keras.layers.Input(shape=(IMG_SIZE, IMG_SIZE, 1))

## Feature Extractor
x = tf.keras.layers.Conv2D(16, activation="relu", kernel_size=3,
                             input_shape=(IMG_SIZE, IMG_SIZE, 1))(inputs)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.AveragePooling2D((2,2))(x)
x = tf.keras.layers.Dropout(0.4)(x)

x = tf.keras.layers.Conv2D(32, kernel_size=3, activation="relu")(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.AveragePooling2D((2,2))(x)
x = tf.keras.layers.Dropout(0.4)(x)

x = tf.keras.layers.Conv2D(64, kernel_size=3, activation="relu")(x)
# x = tf.keras.layers.Conv2D(64, kernel_size=3, activation="relu")(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.AveragePooling2D((2,2))(x)
x = tf.keras.layers.Dropout(0.4)(x)

x = tf.keras.layers.Conv2D(64, kernel_size=3, activation="relu")(x)
x = tf.keras.layers.AveragePooling2D((2,2))(x)
x = tf.keras.layers.BatchNormalization()(x)  #
x = tf.keras.layers.Dropout(0.3)(x)#

x = tf.keras.layers.Conv2D(128, kernel_size=3, activation="relu")(x)
# x = tf.keras.layers.Conv2D(128, kernel_size=3, activation="relu")(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.AveragePooling2D((2,2))(x)
x = tf.keras.layers.Dropout(0.4)(x)

x = tf.keras.layers.Conv2D(256, kernel_size=3, activation="relu")(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.AveragePooling2D((2,2))(x)
x = tf.keras.layers.Dropout(0.4)(x)

x = tf.keras.layers.Conv2D(512, kernel_size=3, activation="relu")(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.AveragePooling2D((2,2))(x)
x = tf.keras.layers.Dropout(0.4)(x)






## Dense Layers
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(32, activation="relu")(x)
x = tf.keras.layers.Dropout(0.4)(x)
feature = tf.keras.layers.Dense(64, activation = 'relu')(x)

## Classification head
x = tf.keras.layers.Dense(128, activation = 'relu')(feature)
x = tf.keras.layers.Dense(256, activation = 'relu')(x)
x = tf.keras.layers.Dropout(0.4)(x)
x = tf.keras.layers.Dense(1024, activation = 'relu')(x)
classification_output = tf.keras.layers.Dense(1, activation="sigmoid", name="classification")(x)

## Localization Head
x = tf.keras.layers.Dense(128, activation = 'relu')(feature)
x = tf.keras.layers.Dense(256, activation = 'relu')(x)
x = tf.keras.layers.Dropout(0.4)(x)
x = tf.keras.layers.Dense(1024, activation = 'relu')(x)
localization_output = tf.keras.layers.Dense(units=3, activation = 'relu', name="localization")(x)


model = tf.keras.Model(inputs=inputs, outputs=[classification_output, localization_output])


model.compile(optimizer=Adam(learning_rate=0.0001),
              loss={
                  'classification': "binary_crossentropy",
                  'localization':"mse"
              },
              loss_weights={
                  'classification': 1.0,
                  'localization': 1.0
              },
              metrics={'classification': ['accuracy', AUC()],
                       'localization': ['mse', r_squared]})
model.summary()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 512, 512,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 510, 510,  │        160 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 510, 510,  │         64 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d   │ (None, 255, 255,  │          0 │ batch_normalizat… │
# │ (AveragePooling2D)  │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 255, 255,  │          0 │ average_pooling2… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 253, 253,  │      4,640 │ dropout[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 253, 253,  │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_1 │ (None, 126, 126,  │          0 │ batch_normalizat… │
# │ (AveragePooling2D)  │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 126, 126,  │          0 │ average_pooling2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 124, 124,  │     18,496 │ dropout_1[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 124, 124,  │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_2 │ (None, 62, 62,    │          0 │ batch_normalizat… │
# │ (AveragePooling2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 62, 62,    │          0 │ average_pooling2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 60, 60,    │     36,928 │ dropout_2[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_3 │ (None, 30, 30,    │          0 │ conv2d_3[0][0]    │
# │ (AveragePooling2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 30, 30,    │        256 │ average_pooling2… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 30, 30,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 28, 28,    │     73,856 │ dropout_3[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_4 │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (AveragePooling2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 14, 14,    │          0 │ average_pooling2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 12, 12,    │    295,168 │ dropout_4[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 12,    │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_5 │ (None, 6, 6, 256) │          0 │ batch_normalizat… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 6, 6, 256) │          0 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 4, 4, 512) │  1,180,160 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 512) │      2,048 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_6 │ (None, 2, 2, 512) │          0 │ batch_normalizat… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 2, 2, 512) │          0 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 2048)      │          0 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 32)        │     65,568 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 32)        │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      2,112 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 128)       │      8,320 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 128)       │      8,320 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 256)       │     33,024 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 256)       │     33,024 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 256)       │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 256)       │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 1024)      │    263,168 │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 1024)      │    263,168 │ dropout_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classification      │ (None, 1)         │      1,025 │ dense_4[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ localization        │ (None, 3)         │      3,075 │ dense_7[0][0]     │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,294,500 (8.75 MB)
#  Trainable params: 2,292,356 (8.74 MB)
#  Non-trainable params: 2,144 (8.38 KB)

# %%
num_epochs = 200

# Fit the model with the training data
history = model.fit(train_dataset,
                    epochs=num_epochs,
                    validation_data=test_dataset,
                    shuffle = True,
                  )
# Out:
# Epoch 1/200
# 2024-05-15 20:17:40.970571: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 3.45549, expected 2.6926
# 2024-05-15 20:17:40.970639: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 3.19187, expected 2.42899
# 2024-05-15 20:17:40.970648: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 3.04121, expected 2.27832
# 2024-05-15 20:17:40.970656: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 3.3637, expected 2.60082
# 2024-05-15 20:17:40.970663: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 3.65672, expected 2.89383
# 2024-05-15 20:17:40.970671: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 4.34674, expected 3.58385
# 2024-05-15 20:17:40.970679: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 4.38785, expected 3.62496
# 2024-05-15 20:17:40.970686: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 3.0848, expected 2.32191
# 2024-05-15 20:17:40.970694: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 3.2752, expected 2.51231
# 2024-05-15 20:17:40.970701: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 3.88716, expected 3.12427
# 2024-05-15 20:17:40.985118: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[8,16,510,510]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,1,512,512]{3,2,1,0}, f32[16,1,3,3]{3,2,1,0}, f32[16]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-15 20:17:40.985171: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-15 20:17:40.985184: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-15 20:17:40.985195: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-15 20:17:40.985210: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-15 20:17:40.985233: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-05-15 20:17:41.476507: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 3.45549, expected 2.6926
# 2024-05-15 20:17:41.476564: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 3.19187, expected 2.42899
# 2024-05-15 20:17:41.476574: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 3.04121, expected 2.27832
# 2024-05-15 20:17:41.476582: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 3.3637, expected 2.60082
# 2024-05-15 20:17:41.476589: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 3.65672, expected 2.89383
# 2024-05-15 20:17:41.476597: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 4.34674, expected 3.58385
# 2024-05-15 20:17:41.476604: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 4.38785, expected 3.62496
# 2024-05-15 20:17:41.476612: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 3.0848, expected 2.32191
# 2024-05-15 20:17:41.476619: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 3.2752, expected 2.51231
# 2024-05-15 20:17:41.476627: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 3.88716, expected 3.12427
# 2024-05-15 20:17:41.491015: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[8,16,510,510]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,1,512,512]{3,2,1,0}, f32[16,1,3,3]{3,2,1,0}, f32[16]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-15 20:17:41.491065: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-15 20:17:41.491073: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-15 20:17:41.491081: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-15 20:17:41.491088: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-15 20:17:41.491104: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
#   5/114 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - classification_accuracy: 0.3975 - classification_auc: 0.1680 - localization_mse: 0.1244 - localization_r_squared: -0.3878 - loss: 0.8473
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1715804279.063468     122 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1715804279.096127     122 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - classification_accuracy: 0.5126 - classification_auc: 0.6120 - localization_mse: 0.0864 - localization_r_squared: -121747.7734 - loss: 0.7411
# 2024-05-15 20:18:11.674383: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 520200: 2.56547, expected 1.74189
# 2024-05-15 20:18:11.674441: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 520201: 1.88166, expected 1.05808
# 2024-05-15 20:18:11.674451: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 520202: 2.23247, expected 1.40889
# 2024-05-15 20:18:11.674459: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 520203: 2.61692, expected 1.79335
# 2024-05-15 20:18:11.674467: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 520204: 2.68856, expected 1.86499
# 2024-05-15 20:18:11.674475: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 520205: 2.89487, expected 2.0713
# 2024-05-15 20:18:11.674482: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 520206: 2.48264, expected 1.65907
# 2024-05-15 20:18:11.674490: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 520207: 2.3734, expected 1.54983
# 2024-05-15 20:18:11.674498: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 520208: 1.67684, expected 0.853263
# 2024-05-15 20:18:11.674506: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 520209: 2.66433, expected 1.84076
# 2024-05-15 20:18:11.683662: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[5,16,510,510]{3,2,1,0}, u8[0]{0}) custom-call(f32[5,1,512,512]{3,2,1,0}, f32[16,1,3,3]{3,2,1,0}, f32[16]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-15 20:18:11.683709: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-15 20:18:11.683736: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-15 20:18:11.683749: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-15 20:18:11.683760: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-15 20:18:11.683794: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-05-15 20:18:11.923363: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 520200: 2.56547, expected 1.74189
# 2024-05-15 20:18:11.923418: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 520201: 1.88166, expected 1.05808
# 2024-05-15 20:18:11.923433: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 520202: 2.23247, expected 1.40889
# 2024-05-15 20:18:11.923450: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 520203: 2.61692, expected 1.79335
# 2024-05-15 20:18:11.923464: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 520204: 2.68856, expected 1.86499
# 2024-05-15 20:18:11.923476: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 520205: 2.89487, expected 2.0713
# 2024-05-15 20:18:11.923487: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 520206: 2.48264, expected 1.65907
# 2024-05-15 20:18:11.923498: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 520207: 2.3734, expected 1.54983
# 2024-05-15 20:18:11.923509: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 520208: 1.67684, expected 0.853263
# 2024-05-15 20:18:11.923520: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 520209: 2.66433, expected 1.84076
# 2024-05-15 20:18:11.932792: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[5,16,510,510]{3,2,1,0}, u8[0]{0}) custom-call(f32[5,1,512,512]{3,2,1,0}, f32[16,1,3,3]{3,2,1,0}, f32[16]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-15 20:18:11.932836: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-15 20:18:11.932851: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-15 20:18:11.932868: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-15 20:18:11.932880: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-15 20:18:11.932906: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - classification_accuracy: 0.5134 - classification_auc: 0.6135 - localization_mse: 0.0863 - localization_r_squared: -122020.0391 - loss: 0.7404
# W0000 00:00:1715804312.036218     120 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 2024-05-15 20:18:32.775980: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 260100: 3.96542, expected 3.30316
# 2024-05-15 20:18:32.776046: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 260101: 4.19441, expected 3.53215
# 2024-05-15 20:18:32.776061: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 260102: 3.89545, expected 3.23319
# 2024-05-15 20:18:32.776079: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 260103: 3.74718, expected 3.08492
# 2024-05-15 20:18:32.776091: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 260104: 5.50647, expected 4.84421
# 2024-05-15 20:18:32.776102: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 260106: 4.54534, expected 3.88308
# 2024-05-15 20:18:32.776112: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 260107: 4.49124, expected 3.82898
# 2024-05-15 20:18:32.776123: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 260108: 3.52598, expected 2.86372
# 2024-05-15 20:18:32.776133: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 260109: 4.86568, expected 4.20342
# 2024-05-15 20:18:32.776143: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 260110: 4.32909, expected 3.66683
# 2024-05-15 20:18:32.786883: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[6,16,510,510]{3,2,1,0}, u8[0]{0}) custom-call(f32[6,1,512,512]{3,2,1,0}, f32[16,1,3,3]{3,2,1,0}, f32[16]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-15 20:18:32.786932: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-15 20:18:32.786948: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-15 20:18:32.786962: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-15 20:18:32.786973: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-15 20:18:32.787000: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-05-15 20:18:33.072879: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 260100: 3.96542, expected 3.30316
# 2024-05-15 20:18:33.072932: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 260101: 4.19441, expected 3.53215
# 2024-05-15 20:18:33.072948: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 260102: 3.89545, expected 3.23319
# 2024-05-15 20:18:33.072964: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 260103: 3.74718, expected 3.08492
# 2024-05-15 20:18:33.072978: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 260104: 5.50647, expected 4.84421
# 2024-05-15 20:18:33.072989: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 260106: 4.54534, expected 3.88308
# 2024-05-15 20:18:33.073008: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 260107: 4.49124, expected 3.82898
# 2024-05-15 20:18:33.073019: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 260108: 3.52598, expected 2.86372
# 2024-05-15 20:18:33.073030: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 260109: 4.86568, expected 4.20342
# 2024-05-15 20:18:33.073040: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 260110: 4.32909, expected 3.66683
# 2024-05-15 20:18:33.083874: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[6,16,510,510]{3,2,1,0}, u8[0]{0}) custom-call(f32[6,1,512,512]{3,2,1,0}, f32[16,1,3,3]{3,2,1,0}, f32[16]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-15 20:18:33.083930: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-15 20:18:33.083943: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-15 20:18:33.083958: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-15 20:18:33.083969: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-15 20:18:33.083989: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 71s 314ms/step - classification_accuracy: 0.5140 - classification_auc: 0.6150 - localization_mse: 0.0861 - localization_r_squared: -122287.5703 - loss: 0.7398 - val_classification_accuracy: 0.5000 - val_classification_auc: 0.8535 - val_localization_mse: 0.0727 - val_localization_r_squared: 0.0591 - val_loss: 1.0480
# Epoch 2/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.8456 - classification_auc: 0.9140 - localization_mse: 0.0593 - localization_r_squared: -27804.6094 - loss: 0.4421 - val_classification_accuracy: 0.5000 - val_classification_auc: 0.9037 - val_localization_mse: 0.0653 - val_localization_r_squared: 0.1478 - val_loss: 0.9728
# Epoch 3/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9158 - classification_auc: 0.9645 - localization_mse: 0.0443 - localization_r_squared: -8729.9336 - loss: 0.2917 - val_classification_accuracy: 0.5077 - val_classification_auc: 0.9214 - val_localization_mse: 0.0778 - val_localization_r_squared: -0.0854 - val_loss: 1.1003
# Epoch 4/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9174 - classification_auc: 0.9650 - localization_mse: 0.0440 - localization_r_squared: -16202.2803 - loss: 0.2825 - val_classification_accuracy: 0.8103 - val_classification_auc: 0.9381 - val_localization_mse: 0.0605 - val_localization_r_squared: 0.1153 - val_loss: 0.5709
# Epoch 5/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9127 - classification_auc: 0.9558 - localization_mse: 0.0404 - localization_r_squared: 0.4591 - loss: 0.2793 - val_classification_accuracy: 0.8026 - val_classification_auc: 0.9566 - val_localization_mse: 0.0480 - val_localization_r_squared: 0.3452 - val_loss: 0.6446
# Epoch 6/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9449 - classification_auc: 0.9807 - localization_mse: 0.0309 - localization_r_squared: 0.6148 - loss: 0.1992 - val_classification_accuracy: 0.8641 - val_classification_auc: 0.9584 - val_localization_mse: 0.0483 - val_localization_r_squared: 0.3825 - val_loss: 0.3759
# Epoch 7/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - classification_accuracy: 0.9288 - classification_auc: 0.9777 - localization_mse: 0.0308 - localization_r_squared: -64604.9375 - loss: 0.2138 - val_classification_accuracy: 0.8744 - val_classification_auc: 0.9695 - val_localization_mse: 0.0338 - val_localization_r_squared: 0.5611 - val_loss: 0.3145
# Epoch 8/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9477 - classification_auc: 0.9792 - localization_mse: 0.0321 - localization_r_squared: 0.5733 - loss: 0.2081 - val_classification_accuracy: 0.9282 - val_classification_auc: 0.9818 - val_localization_mse: 0.0374 - val_localization_r_squared: 0.5316 - val_loss: 0.1983
# Epoch 9/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9211 - classification_auc: 0.9747 - localization_mse: 0.0342 - localization_r_squared: 0.5276 - loss: 0.2217 - val_classification_accuracy: 0.9205 - val_classification_auc: 0.9763 - val_localization_mse: 0.0611 - val_localization_r_squared: 0.2406 - val_loss: 0.2912
# Epoch 10/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9272 - classification_auc: 0.9818 - localization_mse: 0.0280 - localization_r_squared: -14464.8164 - loss: 0.1968 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9776 - val_localization_mse: 0.0272 - val_localization_r_squared: 0.6595 - val_loss: 0.1981
# Epoch 11/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9527 - classification_auc: 0.9878 - localization_mse: 0.0284 - localization_r_squared: 0.6515 - loss: 0.1584 - val_classification_accuracy: 0.9333 - val_classification_auc: 0.9791 - val_localization_mse: 0.0361 - val_localization_r_squared: 0.5572 - val_loss: 0.2068
# Epoch 12/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9402 - classification_auc: 0.9812 - localization_mse: 0.0310 - localization_r_squared: 0.6028 - loss: 0.1948 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9779 - val_localization_mse: 0.0326 - val_localization_r_squared: 0.5885 - val_loss: 0.2160
# Epoch 13/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9345 - classification_auc: 0.9803 - localization_mse: 0.0259 - localization_r_squared: 0.6701 - loss: 0.1994 - val_classification_accuracy: 0.9385 - val_classification_auc: 0.9822 - val_localization_mse: 0.0337 - val_localization_r_squared: 0.5836 - val_loss: 0.2004
# Epoch 14/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9483 - classification_auc: 0.9839 - localization_mse: 0.0273 - localization_r_squared: -15213.4365 - loss: 0.1745 - val_classification_accuracy: 0.9308 - val_classification_auc: 0.9798 - val_localization_mse: 0.0395 - val_localization_r_squared: 0.5134 - val_loss: 0.2122
# Epoch 15/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9496 - classification_auc: 0.9828 - localization_mse: 0.0289 - localization_r_squared: 0.6205 - loss: 0.1791 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9788 - val_localization_mse: 0.0340 - val_localization_r_squared: 0.5753 - val_loss: 0.1903
# Epoch 16/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9564 - classification_auc: 0.9902 - localization_mse: 0.0219 - localization_r_squared: 0.7179 - loss: 0.1351 - val_classification_accuracy: 0.9385 - val_classification_auc: 0.9778 - val_localization_mse: 0.0388 - val_localization_r_squared: 0.5130 - val_loss: 0.2198
# Epoch 17/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9411 - classification_auc: 0.9820 - localization_mse: 0.0288 - localization_r_squared: 0.6328 - loss: 0.1892 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9827 - val_localization_mse: 0.0340 - val_localization_r_squared: 0.5780 - val_loss: 0.1749
# Epoch 18/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9536 - classification_auc: 0.9896 - localization_mse: 0.0228 - localization_r_squared: 0.7137 - loss: 0.1462 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9832 - val_localization_mse: 0.0389 - val_localization_r_squared: 0.5188 - val_loss: 0.1761
# Epoch 19/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9581 - classification_auc: 0.9864 - localization_mse: 0.0232 - localization_r_squared: -4145.9463 - loss: 0.1508 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9850 - val_localization_mse: 0.0349 - val_localization_r_squared: 0.5731 - val_loss: 0.1639
# Epoch 20/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9495 - classification_auc: 0.9836 - localization_mse: 0.0242 - localization_r_squared: 0.6781 - loss: 0.1747 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9864 - val_localization_mse: 0.0308 - val_localization_r_squared: 0.6226 - val_loss: 0.1688
# Epoch 21/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9387 - classification_auc: 0.9818 - localization_mse: 0.0290 - localization_r_squared: -1061.0491 - loss: 0.1891 - val_classification_accuracy: 0.9333 - val_classification_auc: 0.9804 - val_localization_mse: 0.0335 - val_localization_r_squared: 0.5761 - val_loss: 0.1839
# Epoch 22/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9639 - classification_auc: 0.9845 - localization_mse: 0.0237 - localization_r_squared: -87594.4453 - loss: 0.1520 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9826 - val_localization_mse: 0.0279 - val_localization_r_squared: 0.6554 - val_loss: 0.1709
# Epoch 23/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9683 - classification_auc: 0.9924 - localization_mse: 0.0208 - localization_r_squared: 0.7257 - loss: 0.1187 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9838 - val_localization_mse: 0.0287 - val_localization_r_squared: 0.6468 - val_loss: 0.1675
# Epoch 24/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9630 - classification_auc: 0.9868 - localization_mse: 0.0213 - localization_r_squared: 0.7242 - loss: 0.1424 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9872 - val_localization_mse: 0.0291 - val_localization_r_squared: 0.6435 - val_loss: 0.1680
# Epoch 25/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9563 - classification_auc: 0.9904 - localization_mse: 0.0221 - localization_r_squared: -2989.3833 - loss: 0.1301 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9821 - val_localization_mse: 0.0257 - val_localization_r_squared: 0.6811 - val_loss: 0.1877
# Epoch 26/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9577 - classification_auc: 0.9908 - localization_mse: 0.0206 - localization_r_squared: 0.7447 - loss: 0.1254 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9864 - val_localization_mse: 0.0262 - val_localization_r_squared: 0.6759 - val_loss: 0.1738
# Epoch 27/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - classification_accuracy: 0.9543 - classification_auc: 0.9860 - localization_mse: 0.0209 - localization_r_squared: -37537.6133 - loss: 0.1565 - val_classification_accuracy: 0.9487 - val_classification_auc: 0.9819 - val_localization_mse: 0.0260 - val_localization_r_squared: 0.6767 - val_loss: 0.1730
# Epoch 28/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9484 - classification_auc: 0.9884 - localization_mse: 0.0206 - localization_r_squared: 0.7341 - loss: 0.1363 - val_classification_accuracy: 0.9359 - val_classification_auc: 0.9827 - val_localization_mse: 0.0279 - val_localization_r_squared: 0.6552 - val_loss: 0.1812
# Epoch 29/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9500 - classification_auc: 0.9843 - localization_mse: 0.0243 - localization_r_squared: 0.6774 - loss: 0.1678 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9840 - val_localization_mse: 0.0254 - val_localization_r_squared: 0.6845 - val_loss: 0.1749
# Epoch 30/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9694 - classification_auc: 0.9929 - localization_mse: 0.0184 - localization_r_squared: -36370.3281 - loss: 0.1108 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9855 - val_localization_mse: 0.0252 - val_localization_r_squared: 0.6884 - val_loss: 0.1576
# Epoch 31/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9665 - classification_auc: 0.9928 - localization_mse: 0.0191 - localization_r_squared: -426.3558 - loss: 0.1141 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9880 - val_localization_mse: 0.0241 - val_localization_r_squared: 0.7017 - val_loss: 0.1594
# Epoch 32/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9692 - classification_auc: 0.9936 - localization_mse: 0.0185 - localization_r_squared: -434.3393 - loss: 0.1080 - val_classification_accuracy: 0.9359 - val_classification_auc: 0.9819 - val_localization_mse: 0.0248 - val_localization_r_squared: 0.6937 - val_loss: 0.1670
# Epoch 33/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9608 - classification_auc: 0.9931 - localization_mse: 0.0195 - localization_r_squared: -1095.2773 - loss: 0.1233 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9900 - val_localization_mse: 0.0212 - val_localization_r_squared: 0.7332 - val_loss: 0.1487
# Epoch 34/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9614 - classification_auc: 0.9893 - localization_mse: 0.0199 - localization_r_squared: -114.1935 - loss: 0.1287 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9821 - val_localization_mse: 0.0223 - val_localization_r_squared: 0.7196 - val_loss: 0.1614
# Epoch 35/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9544 - classification_auc: 0.9899 - localization_mse: 0.0191 - localization_r_squared: 0.7503 - loss: 0.1300 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9810 - val_localization_mse: 0.0232 - val_localization_r_squared: 0.7069 - val_loss: 0.1648
# Epoch 36/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9642 - classification_auc: 0.9944 - localization_mse: 0.0188 - localization_r_squared: 0.7699 - loss: 0.1039 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9799 - val_localization_mse: 0.0227 - val_localization_r_squared: 0.7147 - val_loss: 0.1655
# Epoch 37/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9695 - classification_auc: 0.9922 - localization_mse: 0.0164 - localization_r_squared: 0.7634 - loss: 0.1091 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9844 - val_localization_mse: 0.0223 - val_localization_r_squared: 0.7195 - val_loss: 0.1499
# Epoch 38/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9647 - classification_auc: 0.9934 - localization_mse: 0.0174 - localization_r_squared: 0.7739 - loss: 0.1044 - val_classification_accuracy: 0.9333 - val_classification_auc: 0.9836 - val_localization_mse: 0.0269 - val_localization_r_squared: 0.6680 - val_loss: 0.1950
# Epoch 39/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9637 - classification_auc: 0.9937 - localization_mse: 0.0189 - localization_r_squared: 0.7606 - loss: 0.1103 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9854 - val_localization_mse: 0.0208 - val_localization_r_squared: 0.7371 - val_loss: 0.1427
# Epoch 40/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9561 - classification_auc: 0.9898 - localization_mse: 0.0182 - localization_r_squared: -749.0189 - loss: 0.1250 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9865 - val_localization_mse: 0.0225 - val_localization_r_squared: 0.7232 - val_loss: 0.1585
# Epoch 41/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9679 - classification_auc: 0.9922 - localization_mse: 0.0174 - localization_r_squared: 0.7716 - loss: 0.1091 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9737 - val_localization_mse: 0.0240 - val_localization_r_squared: 0.6986 - val_loss: 0.1822
# Epoch 42/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9699 - classification_auc: 0.9934 - localization_mse: 0.0175 - localization_r_squared: -5240.3594 - loss: 0.1017 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9840 - val_localization_mse: 0.0212 - val_localization_r_squared: 0.7377 - val_loss: 0.1625
# Epoch 43/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9621 - classification_auc: 0.9916 - localization_mse: 0.0187 - localization_r_squared: -78088.6797 - loss: 0.1175 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9848 - val_localization_mse: 0.0200 - val_localization_r_squared: 0.7487 - val_loss: 0.1487
# Epoch 44/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9604 - classification_auc: 0.9915 - localization_mse: 0.0162 - localization_r_squared: 0.7695 - loss: 0.1162 - val_classification_accuracy: 0.9487 - val_classification_auc: 0.9872 - val_localization_mse: 0.0182 - val_localization_r_squared: 0.7705 - val_loss: 0.1474
# Epoch 45/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9716 - classification_auc: 0.9946 - localization_mse: 0.0151 - localization_r_squared: -1870.2433 - loss: 0.0966 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9829 - val_localization_mse: 0.0200 - val_localization_r_squared: 0.7472 - val_loss: 0.1525
# Epoch 46/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9655 - classification_auc: 0.9853 - localization_mse: 0.0152 - localization_r_squared: -2454.2190 - loss: 0.0969 - val_classification_accuracy: 0.9487 - val_classification_auc: 0.9862 - val_localization_mse: 0.0196 - val_localization_r_squared: 0.7545 - val_loss: 0.1416
# Epoch 47/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9769 - classification_auc: 0.9967 - localization_mse: 0.0151 - localization_r_squared: 0.8071 - loss: 0.0838 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9863 - val_localization_mse: 0.0216 - val_localization_r_squared: 0.7322 - val_loss: 0.1523
# Epoch 48/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9602 - classification_auc: 0.9957 - localization_mse: 0.0151 - localization_r_squared: 0.7959 - loss: 0.1007 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9846 - val_localization_mse: 0.0212 - val_localization_r_squared: 0.7327 - val_loss: 0.1575
# Epoch 49/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9701 - classification_auc: 0.9939 - localization_mse: 0.0163 - localization_r_squared: 0.8016 - loss: 0.1026 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9830 - val_localization_mse: 0.0216 - val_localization_r_squared: 0.7254 - val_loss: 0.1663
# Epoch 50/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9718 - classification_auc: 0.9944 - localization_mse: 0.0155 - localization_r_squared: -1486.0051 - loss: 0.0965 - val_classification_accuracy: 0.9487 - val_classification_auc: 0.9868 - val_localization_mse: 0.0192 - val_localization_r_squared: 0.7578 - val_loss: 0.1449
# Epoch 51/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9675 - classification_auc: 0.9937 - localization_mse: 0.0153 - localization_r_squared: 0.8002 - loss: 0.1025 - val_classification_accuracy: 0.9385 - val_classification_auc: 0.9829 - val_localization_mse: 0.0193 - val_localization_r_squared: 0.7540 - val_loss: 0.1610
# Epoch 52/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9684 - classification_auc: 0.9874 - localization_mse: 0.0166 - localization_r_squared: 0.7267 - loss: 0.1408 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9846 - val_localization_mse: 0.0184 - val_localization_r_squared: 0.7651 - val_loss: 0.1521
# Epoch 53/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9700 - classification_auc: 0.9948 - localization_mse: 0.0158 - localization_r_squared: -50884.5234 - loss: 0.0949 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9869 - val_localization_mse: 0.0190 - val_localization_r_squared: 0.7593 - val_loss: 0.1416
# Epoch 54/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - classification_accuracy: 0.9752 - classification_auc: 0.9955 - localization_mse: 0.0147 - localization_r_squared: 0.8225 - loss: 0.0887 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9876 - val_localization_mse: 0.0210 - val_localization_r_squared: 0.7345 - val_loss: 0.1503
# Epoch 55/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9703 - classification_auc: 0.9957 - localization_mse: 0.0160 - localization_r_squared: 0.7986 - loss: 0.0921 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9848 - val_localization_mse: 0.0203 - val_localization_r_squared: 0.7397 - val_loss: 0.1685
# Epoch 56/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9640 - classification_auc: 0.9936 - localization_mse: 0.0169 - localization_r_squared: 0.7300 - loss: 0.1047 - val_classification_accuracy: 0.9359 - val_classification_auc: 0.9837 - val_localization_mse: 0.0200 - val_localization_r_squared: 0.7409 - val_loss: 0.1917
# Epoch 57/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9742 - classification_auc: 0.9965 - localization_mse: 0.0148 - localization_r_squared: 0.8140 - loss: 0.0820 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9870 - val_localization_mse: 0.0187 - val_localization_r_squared: 0.7619 - val_loss: 0.1450
# Epoch 58/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - classification_accuracy: 0.9735 - classification_auc: 0.9945 - localization_mse: 0.0163 - localization_r_squared: 0.8105 - loss: 0.0926 - val_classification_accuracy: 0.9359 - val_classification_auc: 0.9859 - val_localization_mse: 0.0217 - val_localization_r_squared: 0.7303 - val_loss: 0.1797
# Epoch 59/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9719 - classification_auc: 0.9962 - localization_mse: 0.0155 - localization_r_squared: -4618.7456 - loss: 0.0922 - val_classification_accuracy: 0.9487 - val_classification_auc: 0.9862 - val_localization_mse: 0.0193 - val_localization_r_squared: 0.7560 - val_loss: 0.1652
# Epoch 60/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9742 - classification_auc: 0.9957 - localization_mse: 0.0147 - localization_r_squared: 0.8047 - loss: 0.0885 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9878 - val_localization_mse: 0.0191 - val_localization_r_squared: 0.7573 - val_loss: 0.1524
# Epoch 61/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9665 - classification_auc: 0.9947 - localization_mse: 0.0165 - localization_r_squared: -12606.5605 - loss: 0.1010 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9844 - val_localization_mse: 0.0183 - val_localization_r_squared: 0.7663 - val_loss: 0.1532
# Epoch 62/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9624 - classification_auc: 0.9927 - localization_mse: 0.0172 - localization_r_squared: -75897.1406 - loss: 0.1091 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9849 - val_localization_mse: 0.0197 - val_localization_r_squared: 0.7496 - val_loss: 0.1603
# Epoch 63/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9599 - classification_auc: 0.9959 - localization_mse: 0.0155 - localization_r_squared: 0.8017 - loss: 0.1010 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9828 - val_localization_mse: 0.0187 - val_localization_r_squared: 0.7576 - val_loss: 0.1900
# Epoch 64/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9772 - classification_auc: 0.9971 - localization_mse: 0.0155 - localization_r_squared: 0.8077 - loss: 0.0792 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9823 - val_localization_mse: 0.0196 - val_localization_r_squared: 0.7480 - val_loss: 0.1907
# Epoch 65/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9771 - classification_auc: 0.9950 - localization_mse: 0.0135 - localization_r_squared: 0.8361 - loss: 0.0827 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9835 - val_localization_mse: 0.0190 - val_localization_r_squared: 0.7574 - val_loss: 0.1921
# Epoch 66/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9567 - classification_auc: 0.9894 - localization_mse: 0.0165 - localization_r_squared: 0.7847 - loss: 0.1359 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9852 - val_localization_mse: 0.0194 - val_localization_r_squared: 0.7513 - val_loss: 0.1636
# Epoch 67/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9676 - classification_auc: 0.9942 - localization_mse: 0.0130 - localization_r_squared: -13542.8838 - loss: 0.0912 - val_classification_accuracy: 0.9385 - val_classification_auc: 0.9850 - val_localization_mse: 0.0227 - val_localization_r_squared: 0.7195 - val_loss: 0.1679
# Epoch 68/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9445 - classification_auc: 0.9904 - localization_mse: 0.0194 - localization_r_squared: 0.6778 - loss: 0.1318 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9885 - val_localization_mse: 0.0187 - val_localization_r_squared: 0.7646 - val_loss: 0.1485
# Epoch 69/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9590 - classification_auc: 0.9911 - localization_mse: 0.0171 - localization_r_squared: -821.8686 - loss: 0.1169 - val_classification_accuracy: 0.9385 - val_classification_auc: 0.9866 - val_localization_mse: 0.0211 - val_localization_r_squared: 0.7302 - val_loss: 0.1739
# Epoch 70/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9713 - classification_auc: 0.9960 - localization_mse: 0.0146 - localization_r_squared: 0.8168 - loss: 0.0862 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9838 - val_localization_mse: 0.0206 - val_localization_r_squared: 0.7302 - val_loss: 0.1767
# Epoch 71/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9693 - classification_auc: 0.9954 - localization_mse: 0.0153 - localization_r_squared: 0.7987 - loss: 0.0930 - val_classification_accuracy: 0.9487 - val_classification_auc: 0.9866 - val_localization_mse: 0.0186 - val_localization_r_squared: 0.7595 - val_loss: 0.1568
# Epoch 72/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9765 - classification_auc: 0.9952 - localization_mse: 0.0139 - localization_r_squared: 0.8322 - loss: 0.0835 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9862 - val_localization_mse: 0.0192 - val_localization_r_squared: 0.7580 - val_loss: 0.1446
# Epoch 73/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9663 - classification_auc: 0.9944 - localization_mse: 0.0165 - localization_r_squared: 0.7965 - loss: 0.0986 - val_classification_accuracy: 0.9487 - val_classification_auc: 0.9868 - val_localization_mse: 0.0168 - val_localization_r_squared: 0.7836 - val_loss: 0.1447
# Epoch 74/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9726 - classification_auc: 0.9948 - localization_mse: 0.0153 - localization_r_squared: 0.8169 - loss: 0.0916 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9875 - val_localization_mse: 0.0180 - val_localization_r_squared: 0.7699 - val_loss: 0.1456
# Epoch 75/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9665 - classification_auc: 0.9956 - localization_mse: 0.0172 - localization_r_squared: 0.7766 - loss: 0.0958 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9806 - val_localization_mse: 0.0186 - val_localization_r_squared: 0.7575 - val_loss: 0.2116
# Epoch 76/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9689 - classification_auc: 0.9943 - localization_mse: 0.0151 - localization_r_squared: 0.8033 - loss: 0.0985 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9886 - val_localization_mse: 0.0175 - val_localization_r_squared: 0.7771 - val_loss: 0.1409
# Epoch 77/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9721 - classification_auc: 0.9954 - localization_mse: 0.0149 - localization_r_squared: 0.8190 - loss: 0.0871 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9888 - val_localization_mse: 0.0194 - val_localization_r_squared: 0.7598 - val_loss: 0.1553
# Epoch 78/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9606 - classification_auc: 0.9933 - localization_mse: 0.0158 - localization_r_squared: 0.8036 - loss: 0.1061 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9843 - val_localization_mse: 0.0188 - val_localization_r_squared: 0.7615 - val_loss: 0.1913
# Epoch 79/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9596 - classification_auc: 0.9942 - localization_mse: 0.0152 - localization_r_squared: 0.7686 - loss: 0.1016 - val_classification_accuracy: 0.9282 - val_classification_auc: 0.9822 - val_localization_mse: 0.0227 - val_localization_r_squared: 0.7155 - val_loss: 0.1819
# Epoch 80/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9809 - classification_auc: 0.9974 - localization_mse: 0.0145 - localization_r_squared: 0.8197 - loss: 0.0753 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9875 - val_localization_mse: 0.0189 - val_localization_r_squared: 0.7611 - val_loss: 0.1544
# Epoch 81/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9759 - classification_auc: 0.9946 - localization_mse: 0.0143 - localization_r_squared: -908.5465 - loss: 0.1327 - val_classification_accuracy: 0.9385 - val_classification_auc: 0.9884 - val_localization_mse: 0.0201 - val_localization_r_squared: 0.7493 - val_loss: 0.1604
# Epoch 82/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9661 - classification_auc: 0.9941 - localization_mse: 0.0153 - localization_r_squared: 0.7890 - loss: 0.0984 - val_classification_accuracy: 0.9487 - val_classification_auc: 0.9833 - val_localization_mse: 0.0190 - val_localization_r_squared: 0.7538 - val_loss: 0.2096
# Epoch 83/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9740 - classification_auc: 0.9962 - localization_mse: 0.0144 - localization_r_squared: -4406.2393 - loss: 0.0874 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9870 - val_localization_mse: 0.0180 - val_localization_r_squared: 0.7696 - val_loss: 0.1692
# Epoch 84/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9770 - classification_auc: 0.9977 - localization_mse: 0.0131 - localization_r_squared: 0.8240 - loss: 0.0746 - val_classification_accuracy: 0.9359 - val_classification_auc: 0.9815 - val_localization_mse: 0.0223 - val_localization_r_squared: 0.7239 - val_loss: 0.1994
# Epoch 85/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9803 - classification_auc: 0.9975 - localization_mse: 0.0140 - localization_r_squared: 0.8145 - loss: 0.0739 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9864 - val_localization_mse: 0.0180 - val_localization_r_squared: 0.7652 - val_loss: 0.1651
# Epoch 86/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9729 - classification_auc: 0.9953 - localization_mse: 0.0147 - localization_r_squared: -981.5438 - loss: 0.0904 - val_classification_accuracy: 0.9487 - val_classification_auc: 0.9859 - val_localization_mse: 0.0184 - val_localization_r_squared: 0.7609 - val_loss: 0.1792
# Epoch 87/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9815 - classification_auc: 0.9979 - localization_mse: 0.0130 - localization_r_squared: 0.8341 - loss: 0.0679 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9852 - val_localization_mse: 0.0179 - val_localization_r_squared: 0.7708 - val_loss: 0.1608
# Epoch 88/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - classification_accuracy: 0.9739 - classification_auc: 0.9970 - localization_mse: 0.0143 - localization_r_squared: 0.8236 - loss: 0.0790 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9863 - val_localization_mse: 0.0187 - val_localization_r_squared: 0.7600 - val_loss: 0.1639
# Epoch 89/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9740 - classification_auc: 0.9970 - localization_mse: 0.0136 - localization_r_squared: -19191.6582 - loss: 0.0847 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9859 - val_localization_mse: 0.0187 - val_localization_r_squared: 0.7647 - val_loss: 0.1676
# Epoch 90/200
# ...
# Epoch 156/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9822 - classification_auc: 0.9991 - localization_mse: 0.0118 - localization_r_squared: 0.8559 - loss: 0.0473 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9777 - val_localization_mse: 0.0199 - val_localization_r_squared: 0.7365 - val_loss: 0.2665
# Epoch 157/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9856 - classification_auc: 0.9994 - localization_mse: 0.0102 - localization_r_squared: -1967.4097 - loss: 0.0410 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9788 - val_localization_mse: 0.0197 - val_localization_r_squared: 0.7422 - val_loss: 0.2334
# Epoch 158/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - classification_accuracy: 0.9856 - classification_auc: 0.9989 - localization_mse: 0.0117 - localization_r_squared: -275.5168 - loss: 0.0485 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9729 - val_localization_mse: 0.0203 - val_localization_r_squared: 0.7375 - val_loss: 0.3055
# Epoch 159/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9712 - classification_auc: 0.9989 - localization_mse: 0.0125 - localization_r_squared: -104503.8828 - loss: 0.0549 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9773 - val_localization_mse: 0.0195 - val_localization_r_squared: 0.7484 - val_loss: 0.2350
# Epoch 160/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9768 - classification_auc: 0.9988 - localization_mse: 0.0119 - localization_r_squared: -4221.5879 - loss: 0.0576 - val_classification_accuracy: 0.9359 - val_classification_auc: 0.9778 - val_localization_mse: 0.0205 - val_localization_r_squared: 0.7287 - val_loss: 0.2723
# Epoch 161/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9856 - classification_auc: 0.9991 - localization_mse: 0.0108 - localization_r_squared: 0.8593 - loss: 0.0476 - val_classification_accuracy: 0.9385 - val_classification_auc: 0.9763 - val_localization_mse: 0.0207 - val_localization_r_squared: 0.7282 - val_loss: 0.2670
# Epoch 162/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9851 - classification_auc: 0.9991 - localization_mse: 0.0115 - localization_r_squared: 0.8627 - loss: 0.0453 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9766 - val_localization_mse: 0.0196 - val_localization_r_squared: 0.7504 - val_loss: 0.2568
# Epoch 163/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9877 - classification_auc: 0.9984 - localization_mse: 0.0107 - localization_r_squared: 0.8698 - loss: 0.0515 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9741 - val_localization_mse: 0.0202 - val_localization_r_squared: 0.7384 - val_loss: 0.3076
# Epoch 164/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9908 - classification_auc: 0.9994 - localization_mse: 0.0107 - localization_r_squared: 0.8703 - loss: 0.0368 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9654 - val_localization_mse: 0.0201 - val_localization_r_squared: 0.7311 - val_loss: 0.3901
# Epoch 165/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9799 - classification_auc: 0.9991 - localization_mse: 0.0114 - localization_r_squared: -23776.3633 - loss: 0.0507 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9773 - val_localization_mse: 0.0208 - val_localization_r_squared: 0.7237 - val_loss: 0.2672
# Epoch 166/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9851 - classification_auc: 0.9987 - localization_mse: 0.0112 - localization_r_squared: -7550.9878 - loss: 0.0500 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9866 - val_localization_mse: 0.0181 - val_localization_r_squared: 0.7671 - val_loss: 0.1693
# Epoch 167/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9852 - classification_auc: 0.9989 - localization_mse: 0.0116 - localization_r_squared: 0.8424 - loss: 0.0489 - val_classification_accuracy: 0.9487 - val_classification_auc: 0.9831 - val_localization_mse: 0.0192 - val_localization_r_squared: 0.7563 - val_loss: 0.2011
# Epoch 168/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9913 - classification_auc: 0.9994 - localization_mse: 0.0109 - localization_r_squared: 0.8667 - loss: 0.0387 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9754 - val_localization_mse: 0.0204 - val_localization_r_squared: 0.7302 - val_loss: 0.2770
# Epoch 169/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9797 - classification_auc: 0.9990 - localization_mse: 0.0117 - localization_r_squared: 0.8282 - loss: 0.0550 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9731 - val_localization_mse: 0.0203 - val_localization_r_squared: 0.7313 - val_loss: 0.3463
# Epoch 170/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9869 - classification_auc: 0.9989 - localization_mse: 0.0107 - localization_r_squared: 0.8619 - loss: 0.0463 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9768 - val_localization_mse: 0.0202 - val_localization_r_squared: 0.7275 - val_loss: 0.2561
# Epoch 171/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9802 - classification_auc: 0.9991 - localization_mse: 0.0128 - localization_r_squared: -7397.4805 - loss: 0.0463 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9758 - val_localization_mse: 0.0199 - val_localization_r_squared: 0.7367 - val_loss: 0.3048
# Epoch 172/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9821 - classification_auc: 0.9992 - localization_mse: 0.0113 - localization_r_squared: 0.8581 - loss: 0.0498 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9801 - val_localization_mse: 0.0188 - val_localization_r_squared: 0.7606 - val_loss: 0.2345
# Epoch 173/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9811 - classification_auc: 0.9993 - localization_mse: 0.0100 - localization_r_squared: 0.8590 - loss: 0.0417 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9699 - val_localization_mse: 0.0193 - val_localization_r_squared: 0.7484 - val_loss: 0.3068
# Epoch 174/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9889 - classification_auc: 0.9973 - localization_mse: 0.0115 - localization_r_squared: 0.8574 - loss: 0.0488 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9805 - val_localization_mse: 0.0191 - val_localization_r_squared: 0.7583 - val_loss: 0.2212
# Epoch 175/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - classification_accuracy: 0.9763 - classification_auc: 0.9991 - localization_mse: 0.0109 - localization_r_squared: 0.8659 - loss: 0.0501 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9797 - val_localization_mse: 0.0189 - val_localization_r_squared: 0.7566 - val_loss: 0.2286
# Epoch 176/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9869 - classification_auc: 0.9992 - localization_mse: 0.0106 - localization_r_squared: 0.8687 - loss: 0.0436 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9694 - val_localization_mse: 0.0192 - val_localization_r_squared: 0.7516 - val_loss: 0.3240
# Epoch 177/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9727 - classification_auc: 0.9957 - localization_mse: 0.0139 - localization_r_squared: 0.8186 - loss: 0.0850 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9809 - val_localization_mse: 0.0196 - val_localization_r_squared: 0.7441 - val_loss: 0.2384
# Epoch 178/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9819 - classification_auc: 0.9992 - localization_mse: 0.0126 - localization_r_squared: 0.8475 - loss: 0.0524 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9799 - val_localization_mse: 0.0194 - val_localization_r_squared: 0.7495 - val_loss: 0.2260
# Epoch 179/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9851 - classification_auc: 0.9988 - localization_mse: 0.0106 - localization_r_squared: 0.8735 - loss: 0.0486 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9759 - val_localization_mse: 0.0209 - val_localization_r_squared: 0.7233 - val_loss: 0.2830
# Epoch 180/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9882 - classification_auc: 0.9990 - localization_mse: 0.0102 - localization_r_squared: 0.8793 - loss: 0.0456 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9797 - val_localization_mse: 0.0201 - val_localization_r_squared: 0.7365 - val_loss: 0.2412
# Epoch 181/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9885 - classification_auc: 0.9996 - localization_mse: 0.0097 - localization_r_squared: -124.1417 - loss: 0.0368 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9751 - val_localization_mse: 0.0202 - val_localization_r_squared: 0.7321 - val_loss: 0.2918
# Epoch 182/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9914 - classification_auc: 0.9997 - localization_mse: 0.0106 - localization_r_squared: 0.8676 - loss: 0.0336 - val_classification_accuracy: 0.9359 - val_classification_auc: 0.9682 - val_localization_mse: 0.0208 - val_localization_r_squared: 0.7208 - val_loss: 0.2993
# Epoch 183/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9779 - classification_auc: 0.9990 - localization_mse: 0.0123 - localization_r_squared: 0.8369 - loss: 0.0493 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9735 - val_localization_mse: 0.0200 - val_localization_r_squared: 0.7416 - val_loss: 0.3185
# Epoch 184/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9734 - classification_auc: 0.9969 - localization_mse: 0.0131 - localization_r_squared: -67.6807 - loss: 0.0838 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9792 - val_localization_mse: 0.0201 - val_localization_r_squared: 0.7294 - val_loss: 0.2416
# Epoch 185/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9778 - classification_auc: 0.9988 - localization_mse: 0.0124 - localization_r_squared: 0.8413 - loss: 0.0561 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9804 - val_localization_mse: 0.0200 - val_localization_r_squared: 0.7326 - val_loss: 0.2273
# Epoch 186/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9728 - classification_auc: 0.9985 - localization_mse: 0.0127 - localization_r_squared: -2214.2854 - loss: 0.0662 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9749 - val_localization_mse: 0.0195 - val_localization_r_squared: 0.7481 - val_loss: 0.2521
# Epoch 187/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9852 - classification_auc: 0.9995 - localization_mse: 0.0109 - localization_r_squared: 0.8542 - loss: 0.0400 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9760 - val_localization_mse: 0.0193 - val_localization_r_squared: 0.7533 - val_loss: 0.2433
# Epoch 188/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9884 - classification_auc: 0.9996 - localization_mse: 0.0103 - localization_r_squared: 0.8706 - loss: 0.0329 - val_classification_accuracy: 0.9487 - val_classification_auc: 0.9762 - val_localization_mse: 0.0195 - val_localization_r_squared: 0.7507 - val_loss: 0.2453
# Epoch 189/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9872 - classification_auc: 0.9997 - localization_mse: 0.0095 - localization_r_squared: 0.8817 - loss: 0.0356 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9762 - val_localization_mse: 0.0199 - val_localization_r_squared: 0.7384 - val_loss: 0.2659
# Epoch 190/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9922 - classification_auc: 0.9994 - localization_mse: 0.0096 - localization_r_squared: 0.8749 - loss: 0.0362 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9778 - val_localization_mse: 0.0204 - val_localization_r_squared: 0.7327 - val_loss: 0.2775
# Epoch 191/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9835 - classification_auc: 0.9994 - localization_mse: 0.0104 - localization_r_squared: -394.3831 - loss: 0.0468 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9747 - val_localization_mse: 0.0196 - val_localization_r_squared: 0.7369 - val_loss: 0.3077
# Epoch 192/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9885 - classification_auc: 0.9997 - localization_mse: 0.0107 - localization_r_squared: 0.8628 - loss: 0.0337 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9722 - val_localization_mse: 0.0200 - val_localization_r_squared: 0.7397 - val_loss: 0.3016
# Epoch 193/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9754 - classification_auc: 0.9975 - localization_mse: 0.0124 - localization_r_squared: 0.8503 - loss: 0.0606 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9756 - val_localization_mse: 0.0199 - val_localization_r_squared: 0.7432 - val_loss: 0.2397
# Epoch 194/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9852 - classification_auc: 0.9996 - localization_mse: 0.0098 - localization_r_squared: 0.8778 - loss: 0.0345 - val_classification_accuracy: 0.9385 - val_classification_auc: 0.9712 - val_localization_mse: 0.0199 - val_localization_r_squared: 0.7356 - val_loss: 0.3202
# Epoch 195/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9816 - classification_auc: 0.9983 - localization_mse: 0.0117 - localization_r_squared: 0.8497 - loss: 0.0589 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9827 - val_localization_mse: 0.0193 - val_localization_r_squared: 0.7476 - val_loss: 0.2254
# Epoch 196/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9796 - classification_auc: 0.9997 - localization_mse: 0.0103 - localization_r_squared: 0.8719 - loss: 0.0378 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9631 - val_localization_mse: 0.0200 - val_localization_r_squared: 0.7365 - val_loss: 0.4037
# Epoch 197/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9842 - classification_auc: 0.9995 - localization_mse: 0.0099 - localization_r_squared: 0.8726 - loss: 0.0399 - val_classification_accuracy: 0.9462 - val_classification_auc: 0.9690 - val_localization_mse: 0.0190 - val_localization_r_squared: 0.7533 - val_loss: 0.3051
# Epoch 198/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9878 - classification_auc: 0.9994 - localization_mse: 0.0108 - localization_r_squared: 0.8620 - loss: 0.0403 - val_classification_accuracy: 0.9410 - val_classification_auc: 0.9801 - val_localization_mse: 0.0201 - val_localization_r_squared: 0.7388 - val_loss: 0.2408
# Epoch 199/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - classification_accuracy: 0.9876 - classification_auc: 0.9996 - localization_mse: 0.0099 - localization_r_squared: -35555.8047 - loss: 0.0386 - val_classification_accuracy: 0.9436 - val_classification_auc: 0.9685 - val_localization_mse: 0.0192 - val_localization_r_squared: 0.7410 - val_loss: 0.3190
# Epoch 200/200
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - classification_accuracy: 0.9718 - classification_auc: 0.9990 - localization_mse: 0.0122 - localization_r_squared: 0.8509 - loss: 0.0516 - val_classification_accuracy: 0.9359 - val_classification_auc: 0.9778 - val_localization_mse: 0.0203 - val_localization_r_squared: 0.7286 - val_loss: 0.2773

# %%
# Plot training and validation accuracy
plt.plot(history.history['classification_accuracy'], label='Training Accuracy')
plt.plot(history.history['val_classification_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Classification Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training and validation AUC
plt.plot(history.history['classification_auc'], label='Training ')
plt.plot(history.history['val_classification_auc'], label='Validation')
plt.title('Training and Validation Classification AUC')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training and validation loss
plt.plot(history.history['localization_mse'], label='Training MSE')
plt.plot(history.history['val_localization_mse'], label='Validation MSE')
plt.title('Training and Validation (Localization) Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training and validation r^2
plt.plot(history.history['localization_r_squared'], label='Training R^2')
plt.plot(history.history['val_localization_r_squared'], label='Validation R^2')
plt.title('Training and Validation R Squared Metric')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim(0,1)
plt.legend()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, roc_auc_score, precision_score, recall_score


# Make predictions on the test dataset
predictions = model.predict(test_dataset)

# Extracting classification predictions from the model output
classification_predictions = predictions[0]
classification_predictions = (classification_predictions > .9).astype('int32').flatten()

# Extracting true labels from the test dataset
true_labels = []
for batch, labels_batch in test_dataset:
    for labels in labels_batch['classification']:
        true_labels.append(labels.numpy())
        
true_labels = np.array(true_labels)
    

# Map numeric labels to class names
class_names = {
    0: "Normal",
    1: "Malignant"
}

# Compute the confusion matrix
conf_matrix = confusion_matrix(true_labels, classification_predictions)
# Calculate metrics
accuracy = accuracy_score(true_labels, classification_predictions)
f1 = f1_score(true_labels, classification_predictions)
auc = roc_auc_score(true_labels, classification_predictions)
precision = precision_score(true_labels, classification_predictions)
recall = recall_score(true_labels, classification_predictions)

# Plot the confusion matrix with seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='g', cbar=False)

# Set labels and title
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Test Confusion Matrix')

# Set ticks
tick_labels = [class_names[i] for i in range(len(class_names))]
plt.xticks(np.arange(len(class_names)) + 0.5, tick_labels)
plt.yticks(np.arange(len(class_names)) + 0.5, tick_labels, rotation=0)

plt.show()

# Print metrics
print("Accuracy:", accuracy)
print("F1 Score:", f1)
print("AUC:", auc)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# 29/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# W0000 00:00:1715805235.453576     121 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step
# Accuracy: 0.941025641025641
# F1 Score: 0.9386666666666666
# AUC: 0.9410256410256409
# Precision: 0.9777777777777777
# Recall: 0.9025641025641026

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, roc_auc_score, precision_score, recall_score

train_dataset_1 = training_dataset.batch(BATCH_SIZE).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# Make predictions on the test dataset
predictions = model.predict(train_dataset_1)

# Extracting classification predictions from the model output
classification_predictions = predictions[0]
classification_predictions = (classification_predictions > .9).astype('int32').flatten()

# Extracting true labels from the test dataset
true_labels = []
for batch, labels_batch in train_dataset_1:
    for labels in labels_batch['classification']:
        true_labels.append(labels.numpy())
        
true_labels = np.array(true_labels)
    

# Map numeric labels to class names
class_names = {
    0: "Normal",
    1: "Malignant"
}

# Compute the confusion matrix
conf_matrix = confusion_matrix(true_labels, classification_predictions)
# Calculate metrics
accuracy = accuracy_score(true_labels, classification_predictions)
f1 = f1_score(true_labels, classification_predictions)
auc = roc_auc_score(true_labels, classification_predictions)
precision = precision_score(true_labels, classification_predictions)
recall = recall_score(true_labels, classification_predictions)

# Plot the confusion matrix with seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='g', cbar=False)

# Set labels and title
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Training Confusion Matrix')

# Set ticks
tick_labels = [class_names[i] for i in range(len(class_names))]
plt.xticks(np.arange(len(class_names)) + 0.5, tick_labels)
plt.yticks(np.arange(len(class_names)) + 0.5, tick_labels, rotation=0)

plt.show()

# Print metrics
print("Accuracy:", accuracy)
print("F1 Score:", f1)
print("AUC:", auc)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Accuracy: 0.977997799779978
# F1 Score: 0.9775280898876404
# AUC: 0.9779759887689403
# Precision: 0.9977064220183486
# Recall: 0.9581497797356828

# %%
import numpy as np
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Make predictions on the test dataset
predictions = model.predict(test_dataset)

# Extracting classification predictions from the model output
classification_predictions = predictions[0]
classification_predictions = (classification_predictions > .9).astype('int32').flatten()

# Extracting true labels from the test dataset
true_labels = []
for batch, labels_batch in test_dataset:
    for labels in labels_batch['classification']:
        true_labels.append(labels.numpy())
        
true_labels = np.array(true_labels)

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(true_labels, classification_predictions)

# Compute area under the curve (AUC)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (AUC = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
